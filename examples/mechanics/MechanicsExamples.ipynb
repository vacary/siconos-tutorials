# %%
import sys
import numpy as np
sys.path.append("../toolbox")
from tools import plot_and_compare
import matplotlib.pyplot as plt
import subprocess

# %% [markdown]
# # 2D Rigid Bodies

# %%
ref = np.loadtxt("2DRigidBodies/Ball2D_kernel_only_with_friction.ref", skiprows=1)
try: 
    mine = np.loadtxt("2DRigidBodies/Ball2D_kernel_only_with_friction.dat")
except:
    subprocess.run("cd 2DRigidBodies/ && siconos Ball2D_kernel_only_with_friction.cpp", shell=True, check=True)
try:
    main = np.loadtxt("2DRigidBodies/ref_main.ref", skiprows=1)
except:
    main = None
    
plot_and_compare(ref, mine, main)

# %%
ref = np.loadtxt("2DRigidBodies/Ball2D_kernel_only.ref", skiprows=1)
mine = np.loadtxt("2DRigidBodies/Ball2D_kernel_only.dat")
plot_and_compare(mine, ref)

# %% [markdown]
# # BouncingBall

# %%
ref = np.loadtxt("BouncingBall/BouncingBallTS-CompliantContact.ref", skiprows=1)
try: 
    mine = np.loadtxt("BouncingBall/BouncingBallTS-CompliantContact.dat")
except:
    subprocess.run("cd BouncingBall && siconos BouncingBallTS.cpp && cd -", shell=True, check=True)
plot_and_compare(mine, ref)

# %%
ref = np.loadtxt("BouncingBall/BouncingBallTS-MoreauJeanCombinedProjectionOSI.ref", skiprows=1)
try: 
    mine = np.loadtxt("BouncingBall/BouncingBallTS-MoreauJeanCombinedProjectionOSI.dat")
except:
    subprocess.run("cd BouncingBall && siconos BouncingBallTS-MoreauJeanCombinedProjectionOSI.cpp && cd -", shell=True, check=True)

try:
    main = np.loadtxt("../../../siconos-tutorials-ref/examples/mechanics/BouncingBall/result.dat")
except:
    main= None    
# ref2 = np.loadtxt("BouncingBall/BouncingBallTS.ref", skiprows=1)

#plot_and_compare(mine, ref, ref2, main)
plot_and_compare(mine, main, ref)

# %%
ref = np.loadtxt("BouncingBall/BouncingBallTS-SchatzmanPaoliOSI.ref", skiprows=1)
try: 
    mine = np.loadtxt("BouncingBall/BouncingBallTS-SchatzmanPaoliOSI.dat")
except:
    subprocess.run("cd BouncingBall && siconos BouncingBallTS-SchatzmanPaoliOSI.cpp && cd -", shell=True, check=True)

try:
    main = np.loadtxt("../../../siconos-tutorials-ref/examples/mechanics/BouncingBall/result.dat")
except:
    main= None 

#ref2 = np.loadtxt("BouncingBall/BouncingBallTS.ref", skiprows=1)
#plot_and_compare(mine, main)
plot_and_compare(mine, ref, main)

# %%
ref = np.loadtxt("BouncingBall/BouncingBallTS-D1MinusLinearOSI.ref", skiprows=1)
#ref2 = np.loadtxt("BouncingBall/BouncingBallTS-h5e-4.ref", skiprows=1)
try: 
    mine = np.loadtxt("BouncingBall/BouncingBallTS-D1MinusLinearOSI.dat")
except:
    subprocess.run("cd BouncingBall && siconos BouncingBallTS-D1MinusLinearOSI.cpp && cd -", shell=True, check=True)
try:
    main = np.loadtxt("../../../siconos-tutorials-ref/examples/mechanics/BouncingBall/result_tdg.dat")
except:
    main= None 
plot_and_compare(mine, ref, main)

# %%
ref = np.loadtxt("BouncingBallEventDriven/LinearOscillatorED.ref", skiprows=1)
#ref2 = np.loadtxt("BouncingBall/BouncingBallTS-h5e-4.ref", skiprows=1)
try: 
    mine = np.loadtxt("BouncingBallEventDriven/LinearOscillatorED.dat")
except:
    subprocess.run("cd BouncingBallEventDriven && siconos LinearOscillatorED.cpp && cd -", shell=True, check=True)
try:
    main = np.loadtxt("../../../siconos-tutorials-ref/examples/mechanics/BouncingBallEventDriven/LinearOscillatorED.da")
except:
    main= None 

plot_and_compare(mine,ref, main)

# %%
#ref = np.loadtxt("BouncingBallEventDriven/BouncingBallED.ref", skiprows=1)
#refTS = np.loadtxt("BouncingBall/BouncingBallTS.ref", skiprows=1)
#mine = np.loadtxt("BouncingBallEventDriven/BouncingBallED.dat")
#mineHEM5 = np.loadtxt("BouncingBallEventDriven/BouncingBallED-HEM5.dat")
#main = np.loadtxt("../../../siconos-tutorials-ref/examples/mechanics/BouncingBallEventDriven/result.dat", skiprows=1)
#plot_and_compare(mineHEM5, main)

#plt.figure()
#plt.plot(mine[:,0], mine[:,1], 'r.', refTS[:,0], refTS[:,1], 'b--')
#plt.xlim(1.9,2.1)

# %%
ref = np.loadtxt("NewtonEuler/BouncingBallNETS-WITHPROJ.ref", skiprows=1)
try: 
    mine = np.loadtxt("NewtonEuler/BouncingBallNETS.dat")
except:
    subprocess.run("cd NewtonEuler && siconos BouncingBallNETS.cpp && cd -", shell=True, check=True)
try:
    main = np.loadtxt("../../../siconos-tutorials-ref/examples/mechanics/NewtonEuler/result.dat")
except:
    main= None 
plot_and_compare(mine,ref, main)

# %% [markdown]
# # Ball on moving plane

# %%
plt.plot(mine[:,0], mine[:,18], 'rx')
plt.plot(ref[:,0], ref[:,18], '--o')
plt.xlim(-0.01,.02)
plt.grid("on")

# %%
ref = np.loadtxt("BallOnMovingPlane/BallNewtonEuler.ref", skiprows=1)
mine = np.loadtxt("BallOnMovingPlane/BallNewtonEuler.dat")
try: 
    mine = np.loadtxt("BallOnMovingPlane/BallNewtonEuler.dat")
except:
    subprocess.run("cd BallOnMovingPlane && siconos BallNewtonEuler.cpp && cd -", shell=True, check=True)
plot_and_compare(mine,ref)

# %%
ref = np.loadtxt("BallOnMovingPlane/BallNewtonEulerOnMovingPlane.ref", skiprows=1)
try: 
    mine = np.loadtxt("BallOnMovingPlane/BallNewtonEulerOnMovingPlane.dat")
except:
    subprocess.run("cd BallOnMovingPlane && siconos BallNewtonEulerOnMovingPlane.cpp && cd -", shell=True, check=True)
plot_and_compare(mine,ref)

# %% [markdown]
# # Column of beads

# %%
ref = np.loadtxt("ColumnOfBeads/ColumnOfBeadsTS-CombinedProjection.ref", skiprows=1)
try: 
    mine = np.loadtxt("ColumnOfBeads/ColumnOfBeadsTS-CombinedProjection.dat")
except:
    subprocess.run("cd ColumnOfBeads && siconos ColumnOfBeadsTS-CombinedProjection.cpp && cd -", shell=True, check=True)
try:
    main = np.loadtxt("../../../siconos-tutorials-ref/examples/mechanics/ColumnOfBeads/ColumnOfbeadsTS-CombinedProjectiom.dat")
except:
    main= None 
#ref2 = np.loadtxt("ColumnOfBeads/ColumnOfBeadsTS.ref", skiprows=1)
#plot_and_compare(mine,main)
plot_and_compare(mine,ref, main)

# %% [markdown]
# # Two BB

# %%
ref = np.loadtxt("TwoBouncingBalls/TwoBouncingBallTS-MoreauJeanGOSI.ref", skiprows=1)
try: 
    mine = np.loadtxt("TwoBouncingBalls/TwoBouncingBallTS-MoreauJeanGOSI.dat")
except:
    subprocess.run("cd TwoBouncingBalls && siconos TwoBouncingBallTS-MoreauJeanGOSI.cpp && cd -", shell=True, check=True)
try:
    main = np.loadtxt("../../../siconos-tutorials-ref/examples/mechanics/TwoBouncingBalls/result.dat")
except:
    main= None 
#ref2 = np.loadtxt("ColumnOfBeads/ColumnOfBeadsTS.ref", skiprows=1)
plot_and_compare(mine,ref,main)

# %% [markdown]
# # Impacting Bar

# %%
ref = np.loadtxt("FEM/ImpactingBar/ImpactingBar.ref", skiprows=1)
ref2 = np.loadtxt("FEM/ImpactingBar/ImpactingBar.dat")
mine = np.loadtxt("FEM/ImpactingBar/refpy.dat")
plot_and_compare(mine,ref2)

# %%
ref.shape

# %%
ref = np.loadtxt("FEM/ImpactingBar/ImpactingBarD1MinusLinear.ref", skiprows=1)
ref2 = np.loadtxt("FEM/ImpactingBar/ImpactingBar.ref", skiprows=1)
mine = np.loadtxt("FEM/ImpactingBar/ImpactingBarD1MinusLinear.dat")
main = np.loadtxt("../../../siconos-tutorials-ref/examples/mechanics/FEM/ImpactingBar/ImpactingBarD1MinusLinear.dat")
plot_and_compare(mine,main)

# %% [markdown]
# # NewtonEuler / Fast spinning object

# %%
ref = np.loadtxt("NewtonEuler/result-py.ref")
mine = np.loadtxt("NewtonEuler/result-py.dat")
plot_and_compare(mine,ref)

# %% [markdown]
# # Four Bar Clearance

# %%
ref = np.loadtxt("FourBarLinkageWith3clearance/FourBarClearance.ref", skiprows=1)
mine = np.loadtxt("FourBarLinkageWith3clearance/simu_0.055")
#main = np.loadtxt("../../../siconos-tutorials-ref/examples/mechanics/FourBarLinkageWith3clearance/simu_0.055")
plot_and_compare(mine, ref)

# %% [markdown]
# # Pendulum

# %%
plt.plot(mine[:,0], mine[:,1], 'r--')
plt.plot(ref[:,0], ref[:,1], '--')
plt.xlim(45,46)
plt.ylim(-0.1,0.01)
plt.grid("on")

# %%
ref = np.loadtxt("Pendulum/SimplePendulumResult.ref", skiprows=1)
mine = np.loadtxt("Pendulum/SimplePendulumResult.dat")
plot_and_compare(mine, ref)

# %%
ref = np.loadtxt("Pendulum/DoublePendulumResult.ref", skiprows=1)
mine = np.loadtxt("Pendulum/DoublePendulumResult.dat")
plot_and_compare(mine, ref)

# %%
ref = np.loadtxt("Pendulum/SimplePendulumED_AlphaScheme.ref", skiprows=1)
ref2 = np.loadtxt("Pendulum/SimplePendulumED_Lsodar.ref", skiprows=1)
ref3 = np.loadtxt("Pendulum/SimplePendulumED_LSodar.dat")
mine = np.loadtxt("Pendulum/SimplePendulumED_AlphaScheme.dat")
main = np.loadtxt("../../../siconos-tutorials-ref/examples/mechanics/Pendulum/SimplePendulumED_AlphaScheme.dat")
plot_and_compare(mine, ref, main)

# %%
ref = np.loadtxt("PendulumOnASlider/PendulumSlider.ref", skiprows=1)
mine = np.loadtxt("PendulumOnASlider/PendulumSlider.dat")
plot_and_compare(mine, ref)

# %% [markdown]
# # Rocking Block

# %%
(0.1 * np.sin(np.pi/3.) + 0.05 * np.cos(np.pi/3.))

# %%
mineTS = np.loadtxt("RockingBlockTmp/RockingBlockTS.dat")
mineED = np.loadtxt("RockingBlockTmp/RockingBlockED.dat")
mineEDN = np.loadtxt("RockingBlockTmp/RockingBlockED_NewMarkAlpha.dat")
plot_and_compare(mineTS, mineTS)

# %%
ref = np.loadtxt("RockingBlock/RockingBlockTS.ref", skiprows=1)
mine = np.loadtxt("RockingBlock/RockingBlockTS.dat")
main = np.loadtxt("../../../siconos-tutorials-ref/examples/mechanics/RockingBlock/result.dat")
ED = np.loadtxt("RockingBlock/RockingBlockED.dat")
plot_and_compare(mine, ref)

# %%
ref = np.loadtxt("RockingBlock/RockingBlockTS-Combined.ref.ref", skiprows=1)
mine = np.loadtxt("RockingBlock/RockingBlockTS.dat")
main = np.loadtxt("../../../siconos-tutorials-ref/examples/mechanics/RockingBlock/result.dat")
ED = np.loadtxt("RockingBlock/RockingBlockED.dat")
nrows = mine.shape[0]
for col in range(1, ref.shape[1]):
    plt.figure(col, figsize=(20,5))
    plt.subplot(1,2,1)
    plt.plot(ED[:nrows,0], ED[:nrows,col], '-.')
    plt.plot(mine[:,0], mine[:,col], 'r--')
    #plt.plot(main[:,0], main[:,col], 'x')
    plt.grid('on')
    #plt.ylim(-0.44,-0.38)
    plt.subplot(1,2,2)
    plt.plot(ref[:nrows,0], ref[:nrows,col] - mine[:,col], '+-')
    #plt.xlim(0.55,0.65)

# %%
ref = np.loadtxt("RockingBlock/RockingBlockED.ref", skiprows=1)
mine = np.loadtxt("RockingBlock/RockingBlockED.dat")
main = np.loadtxt("../../../siconos-tutorials-ref/examples/mechanics/RockingBlock/result.dat")
nrows = mine.shape[0]
for col in range(1, ref.shape[1]):
    plt.figure(col, figsize=(20,5))
    plt.subplot(1,2,1)
    plt.plot(ref[:nrows,0], ref[:nrows,col], '-.')
    plt.plot(mine[:,0], mine[:,col], 'r--')
    #plt.plot(main[:,0], main[:,col], 'x')
    plt.grid('on')
    #plt.ylim(-0.44,-0.38)
    plt.subplot(1,2,2)
    plt.plot(ref[:nrows,0], ref[:nrows,col] - mine[:,col], '+-')
    #plt.xlim(0.55,0.65)

# %%
ref = np.loadtxt("RockingBlock/RockingBlockED_NewMarkAlpha.ref", skiprows=1)
mine = np.loadtxt("RockingBlock/RockingBlockED_NewMarkAlpha.dat")
main = np.loadtxt("../../../siconos-tutorials-ref/examples/mechanics/RockingBlock/RockingBlockED_NewMarkAlpha.dat")
ED = np.loadtxt("RockingBlock/RockingBlockED.dat")
nrows = mine.shape[0]
for col in range(1, ref.shape[1]):
    plt.figure(col, figsize=(20,5))
    plt.subplot(1,2,1)
    plt.plot(ref[:nrows,0], ref[:nrows,col], '-.')
    plt.plot(mine[:,0], mine[:,col], 'r--')
    #plt.plot(main[:,0], main[:,col], 'x')
    plt.grid('on')
    #plt.ylim(-0.44,-0.38)
    plt.subplot(1,2,2)
    plt.plot(ref[:nrows,0], ref[:nrows,col] - mine[:,col], '+-')
    #plt.xlim(0.55,0.65)

# %%
ref = np.loadtxt("RockingBlock/RockingBlockED_Lsodar_LZBimpact.ref", skiprows=1)
mine = np.loadtxt("RockingBlock/RockingBlockED_Lsodar_LZBimpact.dat")
main = np.loadtxt("../../../siconos-tutorials-ref/examples/mechanics/RockingBlock/RockingBlockED_Lsodar_LZBimpact.dat")
ED = np.loadtxt("RockingBlock/RockingBlockED.dat")
plot_and_compare(mine, ref)

# %%
refc = np.loadtxt("RockingBlock/RockingBlockTS-Combined.ref", skiprows=1)
refp = np.loadtxt("RockingBlock/RockingBlockTSProj.ref", skiprows=1)
minec = np.loadtxt("RockingBlock/RockingBlockTS-Combined.dat")
minep = np.loadtxt("RockingBlock/RockingBlockTSProj.dat")
main = np.loadtxt("../../../siconos-tutorials-ref/examples/mechanics/RockingBlock/result.dat")
ED = np.loadtxt("RockingBlock/RockingBlockED.dat")
nrows = minec.shape[0]
for col in range(1, refc.shape[1]):
    plt.figure(col, figsize=(20,5))
    plt.subplot(1,2,1)
    plt.plot(refc[:nrows,0], refc[:nrows,col], '-.')
    plt.plot(refp[:nrows,0], refp[:nrows,col], '-.')
    plt.plot(minec[:,0], minec[:,col], 'r--')
    plt.plot(minep[:,0], minep[:,col], 'b--')
    plt.plot(main[:,0], main[:,col], 'y--')
    #plt.plot(main[:,0], main[:,col], 'x')
    plt.grid('on')
    #plt.ylim(-0.44,-0.38)
    plt.subplot(1,2,2)
    plt.plot(refc[:nrows,0], refc[:nrows,col] - minec[:,col], '+-')
    #plt.xlim(0.55,0.65)

# %% [markdown]
# # Slider Crank

# %%
ref = np.loadtxt("SliderCrank/SliderCrankMoreauJeanCombinedProjectionOSI.ref", skiprows=1)
ref2 = np.loadtxt("SliderCrank/SliderCrankMoreauJeanOSI.ref", skiprows=1)
mine = np.loadtxt("SliderCrank/SliderCrankMoreauJeanCombinedProjectionOSI.dat")
main = np.loadtxt("../../../siconos-tutorials-ref/examples/mechanics/SliderCrank/SliderCrankMoreauJeanCombinedProjectionOSI.dat")
plot_and_compare(mine, ref, main)

# %% [markdown]
# # Woodpecker

# %%
ref = np.loadtxt("Woodpecker/Woodpecker.ref", skiprows=1)
mine = np.loadtxt("Woodpecker/Woodpecker.dat")
main = np.loadtxt("../../../siconos-tutorials-ref/examples/mechanics/Woodpecker/result.dat")
#ED = np.loadtxt("RockingBlock/RockingBlockED.dat")
nrows = mine.shape[0]
for col in range(1, ref.shape[1]):
    plt.figure(col, figsize=(20,5))
    plt.subplot(1,2,1)
    plt.plot(ref[:nrows,0], ref[:nrows,col], '-.')
    plt.plot(mine[:,0], mine[:,col], 'r--')
    #plt.plot(main[:,0], main[:,col], 'x')
    plt.grid('on')
    #plt.ylim(-0.44,-0.38)
    plt.subplot(1,2,2)
    plt.plot(ref[:nrows,0], ref[:nrows,col] - mine[:,col], '+-')
    #plt.xlim(0.55,0.65)

# %% [markdown]
# # Rolling friction

# %%
ref = np.loadtxt("RollingFriction/Ball2D_kernel_only_with_rollingfriction.ref", skiprows=1)
mine = np.loadtxt("RollingFriction/Ball2D_kernel_only_with_rollingfriction.dat")
main = np.loadtxt("../../../siconos-tutorials-ref/examples/mechanics/RollingFriction/Ball_2d_with_kernel_only_with_rollingfriction.dat")
ref2 = np.loadtxt("2DRigidBodies/Ball2D_kernel_only_with_friction.ref", skiprows=1)
ref3 = np.loadtxt("2DRigidBodies/Ball2D_kernel_only_with_friction.dat")
plot_and_compare(mine, ref, ref3)

# %%
ref = np.loadtxt("RollingFriction/test_2d_rolling_friction.ref", skiprows=1)
mine = np.loadtxt("RollingFriction/test_2d_rolling_friction.dat")
main = np.loadtxt("RollingFriction/main.dat")
plot_and_compare(mine, ref)

# %% [markdown]
# # Joints

# %%
ref = np.loadtxt("JointsTests/NE_3DS_3Knee_1Prism_MLCP_MoreauJeanCombinedProjection.ref", skiprows=1)
mine = np.loadtxt("JointsTests/NE_3DS_3Knee_1Prism_MLCP_MoreauJeanCombinedProjection.dat")
main = np.loadtxt("../../../siconos-tutorials-ref/examples/mechanics/JointsTests/NE_3DS_3Knee_1Prism_MLCP_MoreauJeanCombinedProjection.dat")
plot_and_compare(mine, ref)

# %%
mine = np.loadtxt("JointsTests/NE_BouncingBeam.dat")
main = np.loadtxt("../../../siconos-tutorials-ref/examples/mechanics/JointsTests/NE_BouncingBeam.dat")
plot_and_compare(mine, main)

# %%
ref = np.loadtxt("JointsTestsWithInternalForces/NE_3DS_3Knee_1Prism_MLCP_withSprings.ref", skiprows=1)
mine = np.loadtxt("JointsTestsWithInternalForces/NE_3DS_3Knee_1Prism_MLCP_withSprings.dat")
main = np.loadtxt("../../../siconos-tutorials-ref/examples/mechanics/JointsTestsWithInternalForces/NE_3DS_3Knee_1Prism_MLCP_withSprings.dat")
plot_and_compare(mine, ref)

# %% [markdown]
# # Bullet Bouncing Box

# %%
ref = np.loadtxt("BulletBouncingBox/BouncingBox.ref", skiprows=1)
mine = np.loadtxt("BulletBouncingBox/BouncingBox.dat")
mine_py = np.loadtxt("BulletBouncingBox/BouncingBox-py.dat")
main = np.loadtxt("../../../siconos-tutorials-ref/examples/mechanics/BulletBouncingBox/result.dat")
plot_and_compare(mine,mine_py)

# %%
ref = np.loadtxt("BulletBouncingBox/result_dynamic.ref", skiprows=1)
mine = np.loadtxt("BulletBouncingBox/result_dynamic.dat")
mine_py = np.loadtxt("BulletBouncingBox/BouncingBoxDynamic-py.dat")
mine_stat = np.loadtxt("BulletBouncingBox/BouncingBox.dat")
main = np.loadtxt("../../../siconos-tutorials-ref/examples/mechanics/BulletBouncingBox/result_dynamic.dat")
plot_and_compare(mine, mine_py)

# %% [markdown]
# # FEM/native

# %%
ref = np.loadtxt("FEM/native/T3_square_200.ref", skiprows=1)
mine = np.loadtxt("FEM/native/T3.dat")
main = np.loadtxt("FEM/native/T3ns.dat")
plot_and_compare(mine, main, ref)

# %%
#ref = np.loadtxt("FEM/native/T3_square_200.ref", skiprows=1)
mine = np.loadtxt("FEM/native/TH4.dat")
main = np.loadtxt("FEM/native/TH4ns.dat")
plot_and_compare(mine, main)

# %%
ref = np.loadtxt("FEM/native/T3_square_200_with_friction.ref", skiprows=1)
mine = np.loadtxt("FEM/native/T3_collision_detection.dat")
other = np.loadtxt("FEM/native/T3_squarens.dat")
plot_and_compare(mine, ref, other)

# %%
plt.plot(ref[:,0], ref[:,1])

# %%
ref = np.loadtxt("FEM/native/Hertz_T3_1612_with_friction.ref", skiprows=1)
mine = np.loadtxt("FEM/native/Hertz_T3_1612.dat")
ns = np.loadtxt("FEM/native/Hertzns.dat")
plot_and_compare(mine,ns)

# %% [markdown]
# # TwoBouncingBalls

# %%
import matplotlib.pyplot as plt

# %%
#plt.plot(ref[:,0], ref[:,1]+0.1, 'r--')
#plt.plot(ref[:,0], ref[:,5]-0.1, 'b--')
plt.plot(mine[:,0], mine[:,1]+0.1, 'y--')
plt.plot(mine[:,0], mine[:,5]-0.1, 'g--')

# %%
ref = np.loadtxt("TwoBouncingBalls/TwoBouncingBallTS-MoreauJeanGOSI.ref", skiprows=1)
mine = np.loadtxt("TwoBouncingBalls/TwoBouncingBallTS-MoreauJeanGOSI.dat")
main = np.loadtxt("../../../siconos-tutorials-ref/examples/mechanics/TwoBouncingBalls/result.dat")
plot_and_compare(mine,ref, main)

# %% [markdown]
# # Joints Tests

# %%
ref = np.loadtxt("JointsTestsWithInternalForces/NE_3DS_3Knee_1Prism_MLCP_withSprings.ref", skiprows=1)
mine = np.loadtxt("JointsTestsWithInternalForces/NE_3DS_3Knee_1Prism_MLCP_withSprings.dat")
#other = np.loadtxt("JointsTestsWithInternalForces/ref.dat")
plot_and_compare(mine,ref)

# %%
# ref = np.loadtxt("JointsTests/NE_BouncingBeam.ref", skiprows=1)
mine = np.loadtxt("JointsTests/NE_BouncingBeam.dat")
other = np.loadtxt("../../../siconos-tutorials-ref/examples/mechanics/JointsTests/NE_BouncingBeam.dat")
plot_and_compare(mine, other)

# %%
ref = np.loadtxt("JointsTests/NE_1DS_1Knee_MLCP.ref", skiprows=1)
mine = np.loadtxt("JointsTests/NE_1DS_1Knee_MLCP.dat")
plot_and_compare(mine, ref)

# %%
ref = np.loadtxt("JointsTests/NE_3DS_3Knee_1Prism_MLCP_MoreauJeanCombinedProjection.ref", skiprows=1)
mine = np.loadtxt("JointsTests/NE_3DS_3Knee_1Prism_MLCP_MoreauJeanCombinedProjection.dat")
other = np.loadtxt("JointsTests/ref.dat")
plot_and_compare(mine, other)

# %%
ref = np.loadtxt("JointsTestsWithBoundaryConditions/NE_3DS_3Knee_1Prism_GMP.ref", skiprows=1)
mine = np.loadtxt("JointsTestsWithBoundaryConditions/NE_3DS_3Knee_1Prism_GMP.dat")
#other = np.loadtxt("JointsTestsWithInternalForces/ref.dat")
plot_and_compare(mine,ref)

# %%
ref = np.loadtxt("JointsTestsWithBoundaryConditions/NE_3DS_3Knee_1Prism_MLCP.ref", skiprows=1)
mine = np.loadtxt("JointsTestsWithBoundaryConditions/NE_3DS_3Knee_1Prism_MLCP.dat")
#other = np.loadtxt("JointsTestsWithInternalForces/ref.dat")
plot_and_compare(mine,ref)

# %%
ref = np.loadtxt("JointsTestsWithInternalForces/NE_1DS_1Knee_MLCP.ref", skiprows=1)
mine = np.loadtxt("JointsTestsWithInternalForces/NE_1DS_1Knee_MLCP.dat")
#other = np.loadtxt("JointsTestsWithInternalForces/ref.dat")
plot_and_compare(mine,ref)

# %%
ref = np.loadtxt("JointsTests/NE_1DS_1Knee_MLCP_MoreauJeanCombinedProjection.ref", skiprows=1)
mine = np.loadtxt("JointsTests/NE_1DS_1Knee_MLCP_MoreauJeanCombinedProjection.dat")
plot_and_compare(mine, ref)

# %%
ref = np.loadtxt("JointsTests/NE_3DS_3Knee_1Prism_MLCP.ref", skiprows=1)
mine = np.loadtxt("JointsTests/NE_3DS_3Knee_1Prism_MLCP.dat")
plot_and_compare(mine, ref)

# %%
ref = np.loadtxt("JointsTests/NE_3DS_3Knee_1Prism_GMP.ref", skiprows=1)
mine = np.loadtxt("JointsTests/NE_3DS_3Knee_1Prism_GMP.dat")
plot_and_compare(mine, ref)

# %%
ref = np.loadtxt("JointsTests/NE_3DS_3Knee_1Prism_MLCP_MoreauJeanCombinedProjection.ref", skiprows=1)
mine = np.loadtxt("JointsTests/NE_3DS_3Knee_1Prism_MLCP_MoreauJeanCombinedProjection.dat")
plot_and_compare(mine, ref)

# %% [markdown]
# # Yoyo

# %%
ref = np.loadtxt("yoyo/yoyo.ref", skiprows=1)
mine = np.loadtxt("yoyo/yoyo.dat")

plot_and_compare(mine,ref)
