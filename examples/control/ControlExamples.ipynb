# %%
import sys
import numpy as np
sys.path.append("../toolbox")
from tools import plot_and_compare
import matplotlib.pyplot as plt

# %% [markdown]
# # SMC

# %%
ref = np.loadtxt("SMC/SMCExampleExplicit.ref", skiprows=1)
mine = np.loadtxt("SMC/SMCExampleExplicit.dat")
plot_and_compare(mine, ref)

# %%
ref = np.loadtxt("SMC/SMCExampleImplicit.ref", skiprows=1)
mine = np.loadtxt("SMC/SMCExampleImplicit.dat")
plot_and_compare(mine, ref)

# %%
ref = np.loadtxt("SMC/SMCExampleImplicitOT2.ref", skiprows=1)
mine = np.loadtxt("SMC/SMCExampleImplicitOT2.dat")
plot_and_compare(mine, ref)

# %% [markdown]
# # Control optimal

# %%
ref = np.loadtxt("OptimalControl/OptimalControl.ref", skiprows=1)
mine = np.loadtxt("OptimalControl/OptimalControl.dat")
plot_and_compare(mine, ref)

# %% [markdown]
# # Relay

# %%
ref = np.loadtxt("Relay/ParallelInverter.ref", skiprows=1)
mine = np.loadtxt("Relay/ParallelInverter.dat")
plot_and_compare(mine, ref)

# %%
ref = np.loadtxt("Relay/RBS-Controller.ref", skiprows=1)
mine = np.loadtxt("Relay/RBS-Controller.dat")
plot_and_compare(mine, ref)
ref = np.loadtxt("Relay/RBS.ref", skiprows=1)
mine = np.loadtxt("Relay/RBS.dat")
plot_and_compare(mine, ref)

# %%
ref = np.loadtxt("Relay/SimpleExampleRelay.ref", skiprows=1)
mine = np.loadtxt("Relay/SimpleExampleRelay.dat")
plot_and_compare(mine, ref)

# %%
ref = np.loadtxt("Relay/Twisting.ref", skiprows=1)
mine = np.loadtxt("Relay/Twisting.dat")
plot_and_compare(mine, ref)

# %% [markdown]
# # Observer LCS

# %%
ref = np.loadtxt("ObserverLCS/ObserverLCS.ref", skiprows=1)
mine = np.loadtxt("ObserverLCS/ObserverLCS.dat")
plot_and_compare(mine, ref)

# %%
ref = np.loadtxt("ObserverLCS/ObserverLCS.ref", skiprows=1)
mine = np.loadtxt("ObserverLCS/ObserverLCS.dat")
plot_and_compare(mine, ref)

# %% [markdown]
# # Two links manipulator

# %%
ref = np.loadtxt("TwoLinkManipulator/TwoLinkManipulator_MultiConstraintsFlexible.ref", skiprows=1)
mine = np.loadtxt("TwoLinkManipulator/TwoLinkManipulator_MultiConstraintsFlexible.dat")
plot_and_compare(mine, ref)
